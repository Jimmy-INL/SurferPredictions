# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.ticker as plticker
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification

# %%
pipe_masters = pd.read_csv('Datasets/surfstatspipemasters.csv' ,encoding = 'UTF-8')
results = pd.read_csv('Datasets/results.csv' ,encoding = 'UTF-8')
rankings = pd.read_csv('Datasets/rankings.csv' ,encoding = 'UTF-8')
fakeheats = pd.read_csv('Datasets/fakeheats.csv' ,encoding = 'UTF-8')

# %%
pipe_masters.head()
# Out:
#              Name    HWP    AHS  2018 HWP  2018 AHS  E.AHS  E.HWP  E.Heats  \
# 0  Gabriel Medina  66.92  13.59     78.57     13.22  13.07  68.18     22.0
# 1   Julian Wilson  59.14  12.55     75.00     12.59   9.71  56.52     23.0
# 2     Jordy Smith  59.57  13.02     59.38     12.78  10.97  41.67     12.0
# 3    Kelly Slater  60.18  13.93     16.67     13.13  13.48  62.50     24.0
# 4   Conner Coffin  42.48  10.77     45.16     11.15  10.83  42.86      7.0
#
#    4-6'   6-8'   8-10+'  Lefts  Rights   Both   Reef  Proj AHS  Placing
# 0  14.07  14.20   13.89  14.29   13.64  14.35  13.83     12.72        1
# 1  12.71  13.17   11.53  12.18   13.60  13.22  12.78     11.16        2
# 2  13.42  14.35   10.26  11.51   14.47  13.98  12.57     11.56        3
# 3  13.19  15.11   15.68  13.97   13.96  13.50  13.87     12.90        3
# 4  11.71  10.93   14.21  10.67   12.25  11.92  10.58     10.52        5

# %%
print(results)
# Out:
#        Round  Heat           Surfer 1           Surfer 2           Surfer 3  \
# 0          1     1        Jordy Smith       Kelly Slater   Frederico Morais
# 1          1     2          Yago Dora        Owen Wright        Miguel Pupo
# 2          1     3     Italo Ferreira          Joan Duru        Keanu Asing
# 3          1     4     Matt Wilkinson      Filipe Toledo        Caio Ibelli
# 4          1     5      Julian Wilson       Tomas Hermes         Seth Moniz
# 5          1     6     Gabriel Medina     Connor O'Leary        Benji Brand
# 6          1     7      Ryan Callinan    Wade Carmichael  Griffin Colapinto
# 7          1     8     Kanoa Igarashi   Michael February    Sebastian Zietz
# 8          1     9      Michel Bourez      Michel Bourez        Ezekiel Lau
# 9          1    10       Jesse Mendes      Conner Coffin      Jeremy Flores
# 10         1    11      Kolohe Andino      Adrian Buchan     Joel Parkinson
# ...

# %%
df = results[(results['Surfer 1'] == 'Gabriel Medina') | (results['Surfer 2'] == 'Gabriel Medina')]
medina = df.iloc[:]
medina.tail()
# Out:
#        Round  Heat        Surfer 1         Surfer 2       Surfer 3  \
# 29         3     6  Gabriel Medina       Seth Moniz            NaN
# 37         4     2  Gabriel Medina  Sebastian Zietz  Michel Bourez
# 41  Quarters     2  Gabriel Medina    Conner Coffin            NaN
# 44     Semis     1     Jordy Smith   Gabriel Medina            NaN
# 46    Finals     1  Gabriel Medina    Julian Wilson            NaN
#
#     Winner of Heat Wave Size
# 29  Gabriel Medina    8-10+'
# 37  Gabriel Medina      6-8'
# 41  Gabriel Medina      6-8'
# 44  Gabriel Medina      6-8'
# 46  Gabriel Medina      6-8'

# %%
df = results[(results['Surfer 1'] == 'Julian Wilson') | (results['Surfer 2'] == 'Julian Wilson')]
wilson = df.iloc[:]
wilson.tail()
# Out:
#        Round  Heat        Surfer 1       Surfer 2        Surfer 3  \
# 31         3     8   Julian Wilson    Miguel Pupo             NaN
# 38         4     3       Yago Dora  Julian Wilson  Joel Parkinson
# 43  Quarters     4   Julian Wilson      Joan Duru             NaN
# 45     Semis     2   Julian Wilson   Kelly Slater             NaN
# 46    Finals     1  Gabriel Medina  Julian Wilson             NaN
#
#     Winner of Heat Wave Size
# 31   Julian Wilson    8-10+'
# 38       Yago Dora      6-8'
# 43   Julian Wilson      6-8'
# 45   Julian Wilson      6-8'
# 46  Gabriel Medina      6-8'

# %%
dfclean = df.drop(['Wave Size','Surfer 3', 'Round', 'Heat'], axis=1)
dfclean.head()
# Out:
#          Surfer 1       Surfer 2 Winner of Heat
# 4   Julian Wilson   Tomas Hermes  Julian Wilson
# 31  Julian Wilson    Miguel Pupo  Julian Wilson
# 38      Yago Dora  Julian Wilson      Yago Dora
# 43  Julian Wilson      Joan Duru  Julian Wilson
# 45  Julian Wilson   Kelly Slater  Julian Wilson

# %%
final = pd.get_dummies(dfclean, prefix=['Surfer 1', 'Surfer 2'], columns=['Surfer 1', 'Surfer 2'])

# Separate X and y sets
X = final.drop(['Winner of Heat'], axis=1)
y = final["Winner of Heat"]


# Separate train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=42)

# %%
final.head()
# Out:
#    Winner of Heat  Surfer 1_Gabriel Medina  Surfer 1_Julian Wilson  \
# 4   Julian Wilson                        0                       1
# 31  Julian Wilson                        0                       1
# 38      Yago Dora                        0                       0
# 43  Julian Wilson                        0                       1
# 45  Julian Wilson                        0                       1
#
#     Surfer 1_Yago Dora  Surfer 2_Joan Duru  Surfer 2_Julian Wilson  \
# 4                    0                   0                       0
# 31                   0                   0                       0
# 38                   1                   0                       1
# 43                   0                   1                       0
# 45                   0                   0                       0
#
#     Surfer 2_Kelly Slater  Surfer 2_Miguel Pupo  Surfer 2_Tomas Hermes
# 4                       0                     0                      1
# ...

# %%
rf = RandomForestClassifier(n_estimators=100, max_depth=20,
                              random_state=0)
rf.fit(X_train, y_train) 


score = rf.score(X_train, y_train)
score2 = rf.score(X_test, y_test)


print("Training set accuracy: ", '%.3f'%(score))
print("Test set accuracy: ", '%.3f'%(score2))
# Out:
# Training set accuracy:  1.000
# Test set accuracy:  1.000

# %%
rankings = pd.read_csv('Datasets/rankings.csv')
fakeheats = pd.read_csv('Datasets/fakeheats.csv')
pred_set = []

# %%
fakeheats.insert(1, 'first_position', fakeheats['Surfer 1'].map(rankings.set_index('Surfer')['Position']))
fakeheats.insert(2, 'second_position', fakeheats['Surfer 2'].map(rankings.set_index('Surfer')['Position']))

# %%
fakeheats.head()
# Out:
#          Surfer 1  first_position  second_position           Surfer 2  \
# 0     Jordy Smith             5.0              8.0      Michel Bourez
# 1  Matt Wilkinson            24.0             32.0        Miguel Pupo
# 2  Joel Parkinson            23.0             15.0  Michael Rodrigues
# 3    Kelly Slater            29.0             30.0      Ryan Callinan
# 4   Julian Wilson             2.0             19.0        Ezekiel Lau
#
#           Surfer 3  Winner of Heat Wave Size
# 0       Seth Moniz             NaN      4-6'
# 1   Connor O'Leary             NaN      4-6'
# 2  Wade Carmichael             NaN      4-6'
# 3      Miguel Pupo             NaN      4-6'
# 4  Willian Cardoso             NaN      4-6'

# %%
for index, row in fakeheats.iterrows():
    if row['first_position'] < row['second_position']:
        pred_set.append({'Surfer 1': row['Surfer 1'], 'Surfer 2': row['Surfer 2'], 'Winner of Heat': None})
    else:
        pred_set.append({'Surfer 1': row['Surfer 2'], 'Surfer 2': row['Surfer 1'], 'Winner of Heat': None})
        
pred_set = pd.DataFrame(pred_set)
backup_pred_set = pred_set
pred_set.head()
# Out:
#             Surfer 1        Surfer 2 Winner of Heat
# 0        Jordy Smith   Michel Bourez           None
# 1     Matt Wilkinson     Miguel Pupo           None
# 2  Michael Rodrigues  Joel Parkinson           None
# 3       Kelly Slater   Ryan Callinan           None
# 4      Julian Wilson     Ezekiel Lau           None

# %%
pred_set = pd.get_dummies(pred_set, prefix=['Surfer 1', 'Surfer 2'], columns=['Surfer 1', 'Surfer 2'])

# Add missing columns compared to the model's training dataset
missing_cols = set(final.columns) - set(pred_set.columns)
for c in missing_cols:
    pred_set[c] = 0
pred_set = pred_set[final.columns]


pred_set = pred_set.drop(['Winner of Heat'], axis=1)
pred_set.head()
# Out:
#    Surfer 1_Gabriel Medina  Surfer 1_Julian Wilson  Surfer 1_Yago Dora  \
# 0                        0                       0                   0
# 1                        0                       0                   0
# 2                        0                       0                   0
# 3                        0                       0                   0
# 4                        0                       1                   0
#
#    Surfer 2_Joan Duru  Surfer 2_Julian Wilson  Surfer 2_Kelly Slater  \
# 0                   0                       0                      0
# 1                   0                       0                      0
# 2                   0                       0                      0
# 3                   0                       0                      0
# 4                   0                       0                      0
#
#    Surfer 2_Miguel Pupo  Surfer 2_Tomas Hermes
# 0                     0                      0
# ...

# %%
#group matches 
predictions = rf.predict(pred_set)
for i in range(fakeheats.shape[0]):
    print(backup_pred_set.iloc[i, 1] + " and " + backup_pred_set.iloc[i, 0])
    if predictions[i] == 1:
        print("Winner: " + backup_pred_set.iloc[i, 1])
    
    else:
        print("Winner: " + backup_pred_set.iloc[i, 0])
    print("")
# Out:
# Michel Bourez and Jordy Smith
# Winner: Jordy Smith
#
# Miguel Pupo and Matt Wilkinson
# Winner: Matt Wilkinson
#
# Joel Parkinson and Michael Rodrigues
# Winner: Michael Rodrigues
#
# Ryan Callinan and Kelly Slater
# Winner: Kelly Slater
#
# Ezekiel Lau and Julian Wilson
# Winner: Julian Wilson
#
# Owen Wright and Gabriel Medina
# Winner: Gabriel Medina
#
# Kelly Slater and Griffin Colapinto
# Winner: Griffin Colapinto
#
# Ryan Callinan and Kanoa Igarashi
# Winner: Kanoa Igarashi
#
# Ezekiel Lau and Owen Wright
# Winner: Owen Wright
#
# Kelly Slater and Tomas Hermes
# Winner: Tomas Hermes
#
# Tomas Hermes and Griffin Colapinto
# Winner: Griffin Colapinto
#
# Ezekiel Lau and Owen Wright
# Winner: Owen Wright
#
# Kanoa Igarashi and Gabriel Medina
# Winner: Gabriel Medina
#
# Kelly Slater and Conner Coffin
# Winner: Conner Coffin
#
# Miguel Pupo and Griffin Colapinto
# Winner: Griffin Colapinto
#
# Ryan Callinan and Conner Coffin
# Winner: Conner Coffin
#
# ...

# %%
semis = [('Jordy Smith', 'Gabriel Medina'),
            ('Kelly Slater', 'Julian Wilson')]

# %%
def cleanpredict(matches, rankings, final, logreg):

    # Initialization of auxiliary list for data cleaning
    positions = []

    # Loop to retrieve each team's position according to the ranking
    for match in matches:
        positions.append(rankings.loc[rankings['Surfer'] == match[0],'Position'].iloc[0])
        positions.append(rankings.loc[rankings['Surfer'] == match[1],'Position'].iloc[0])
    
    # Creating the DataFrame for prediction
    pred_set = []

    # Initializing iterators for while loop
    i = 0
    j = 0

    # 'i' will be the iterator for the 'positions' list, and 'j' for the list of matches (list of tuples)
    while i < len(positions):
        dict1 = {}

        # If position of first team is better then this team will be the 'Team_1' team, and vice-versa
        if positions[i] < positions[i + 1]:
            dict1.update({'Surfer 1': matches[j][0], 'Surfer 2': matches[j][1]})
        else:
            dict1.update({'Surfer 1': matches[j][1], 'Surfer 2': matches[j][0]})

        # Append updated dictionary to the list, that will later be converted into a DataFrame
        pred_set.append(dict1)
        i += 2
        j += 1
        
        # Convert list into DataFrame
    pred_set = pd.DataFrame(pred_set)
    backup_pred_set = pred_set

    # Get dummy variables and drop winning_team column
    pred_set = pd.get_dummies(pred_set, prefix=['Surfer 1', 'Surfer 2'], columns=['Surfer 1', 'Surfer 2'])

    # Add missing columns compared to the model's training dataset
    missing_cols2 = set(final.columns) - set(pred_set.columns)
    for c in missing_cols2:
        pred_set[c] = 0
    pred_set = pred_set[final.columns]

    pred_set = pred_set.drop(['Winner of Heat'], axis=1)

    # Predict!
    predictions = logreg.predict(pred_set)
    for i in range(len(pred_set)):
        print(backup_pred_set.iloc[i, 1] + " and " + backup_pred_set.iloc[i, 0])
        if predictions[i] == 1:
            print("Winner: " + backup_pred_set.iloc[i, 1])
        else:
            print("Winner: " + backup_pred_set.iloc[i, 0])
        print("")

# %%
cleanpredict(semis, rankings, final, rf)
# Out:
# Jordy Smith and Gabriel Medina
# Winner: Gabriel Medina
#
# Kelly Slater and Julian Wilson
# Winner: Julian Wilson

# %%
finalss = [('Gabriel Medina', 'Julian Wilson')]

# %%
cleanpredict(finalss, rankings, final, rf)
# Out:
# Julian Wilson and Gabriel Medina
# Winner: Gabriel Medina

# %%
#Random Heats
heat1 = [('Griffin Colapinto', 'Kelly Slater')]
cleanpredict(heat1, rankings, final, rf)
heat2 = [('Italo Ferreira', 'Kelly Slater')]
cleanpredict(heat2, rankings, final, rf)
heat3 = [('Filipe Toledo', 'Jordy Smith')]
cleanpredict(heat3, rankings, final, rf)
heat4 = [('Filipe Toledo', 'Italo Ferreira')]
cleanpredict(heat4, rankings, final, rf)
heat5 = [('Tomas Hermes', 'Kelly Slater')]
cleanpredict(heat5, rankings, final, rf)
# Out:
# Kelly Slater and Griffin Colapinto
# Winner: Griffin Colapinto
#
# Kelly Slater and Italo Ferreira
# Winner: Italo Ferreira
#
# Jordy Smith and Filipe Toledo
# Winner: Filipe Toledo
#
# Italo Ferreira and Filipe Toledo
# Winner: Filipe Toledo
#
# Kelly Slater and Tomas Hermes
# Winner: Tomas Hermes
